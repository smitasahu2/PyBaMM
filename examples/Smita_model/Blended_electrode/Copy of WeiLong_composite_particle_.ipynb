# %% [markdown]
# # A composite electrode particle model

# %% [markdown]
#  A composite electrode particle model is developed for (negative) electrodes with two phases, e.g. graphite/silicon in LG M50 battery cells. The current version is demonstrated for negative composite electrodes only but is easily extended to positive composite electrodes. The reference is at the end of this notebook.

# %% [markdown]
# ## How to use the model
#
# Let us set up pybamm

# %%
# %pip install pybamm -q    # install PyBaMM if it is not installed
import os
import matplotlib.pyplot as plt
import numpy as np
import pybamm
import pandas as pd
import timeit
from matplotlib import style
style.use('ggplot')
os.chdir(pybamm.__path__[0]+'/..')
pybamm.set_logging_level("INFO")
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Choose the option `{"particle phases": ("2", "1")}` to load the composite electrode particle model by specifying that there are two particle phases (graphite and silicon) in the negative electrode. The parameter set "Chen2020_composite" includes parameters for silicon as a secondary particle

# %%
start = timeit.default_timer()
model = pybamm.lithium_ion.DFN({
    "particle phases": ("2", "1"),
    "open-circuit potential": (("single", "current sigmoid"), "single")
})

model = pybamm.lithium_ion.DFN({
    "particle phases": "2",
    "open-circuit potential": ("single", "current sigmoid"),
        "working electrode": "negative"
})
# model = pybamm.lithium_ion.DFN({
#         "working electrode": "negative",
#     "particle phases": "2",
#     "open-circuit potential":  ("single", "current sigmoid"),
# })

param = pybamm.ParameterValues("Chen2020_composite")

param.update({"Upper voltage cut-off [V]": 4.5})
param.update({"Lower voltage cut-off [V]": 2.5})

param.update({
    "Primary: Maximum concentration in negative electrode [mol.m-3]":28700,
    "Primary: Initial concentration in negative electrode [mol.m-3]":23000,
    "Primary: Negative electrode diffusivity [m2.s-1]":5.5E-14,
    "Secondary: Negative electrode diffusivity [m2.s-1]":1.67E-14,
    "Secondary: Initial concentration in negative electrode [mol.m-3]":277000,
    "Secondary: Maximum concentration in negative electrode [mol.m-3]":278000
})
# Out:
# 2024-07-04 14:56:51.797 - [INFO] base_model._build_model(545): Start building Doyle-Fuller-Newman model
# 2024-07-04 14:56:52.011 - [INFO] base_battery_model.build_model(921): Finish building Doyle-Fuller-Newman model
# 2024-07-04 14:56:52.029 - [INFO] base_model._build_model(545): Start building Doyle-Fuller-Newman model
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 7
#       1 start = timeit.default_timer()
#       2 model = pybamm.lithium_ion.DFN({
#       3     "particle phases": ("2", "1"),
#       4     "open-circuit potential": (("single", "current sigmoid"), "single")
#       5 })
# ----> 7 model = pybamm.lithium_ion.DFN({
#       8     "particle phases": "2",
#       9     "open-circuit potential": ("single", "current sigmoid"),
#      10         "working electrode": "negative"
#      11 })
#      12 # model = pybamm.lithium_ion.DFN({
#      13 #         "working electrode": "negative",
#      14 #     "particle phases": "2",
#      15 #     "open-circuit potential":  ("single", "current sigmoid"),
#      16 # })
#      18 param = pybamm.ParameterValues("Chen2020_composite")
#
# File ~/PyBaMM/env/lib/python3.9/site-packages/pybamm/models/full_battery_models/lithium_ion/dfn.py:32, in DFN.__init__(self, options, name, build)
#      29 self.x_average = False
#      30 super().__init__(options, name)
# ---> 32 self.set_submodels(build)
#      34 pybamm.citations.register("Doyle1993")
#
# File ~/PyBaMM/env/lib/python3.9/site-packages/pybamm/models/full_battery_models/lithium_ion/base_lithium_ion_model.py:59, in BaseModel.set_submodels(self, build)
#      56 self.set_total_interface_submodel()
#      58 if build:
# ---> 59     self.build_model()
#
# File ~/PyBaMM/env/lib/python3.9/site-packages/pybamm/models/full_battery_models/base_battery_model.py:907, in BaseBatteryModel.build_model(self)
#     905 def build_model(self):
#     906     # Build model variables and equations
# --> 907     self._build_model()
#     909     # Set battery specific variables
#     910     pybamm.logger.debug("Setting voltage variables ({})".format(self.name))
#
# File ~/PyBaMM/env/lib/python3.9/site-packages/pybamm/models/base_model.py:550, in BaseModel._build_model(self)
#     547 if self._built_fundamental is False:
#     548     self.build_fundamental()
# --> 550 self.build_coupled_variables()
#     552 self.build_model_equations()
#
# File ~/PyBaMM/env/lib/python3.9/site-packages/pybamm/models/base_model.py:474, in BaseModel.build_coupled_variables(self)
#     467 pybamm.logger.debug(
#     468     "Getting coupled variables for {} submodel ({})".format(
#     469         submodel_name, self.name
#     470     )
#     471 )
#     472 try:
#     473     self.variables.update(
# --> 474         submodel.get_coupled_variables(self.variables)
#     475     )
#     476     submodels.remove(submodel_name)
#     477 except KeyError as key:
#
# File ~/PyBaMM/env/lib/python3.9/site-packages/pybamm/models/submodels/interface/open_circuit_potential/current_sigmoid_ocp.py:63, in CurrentSigmoidOpenCircuitPotential.get_coupled_variables(self, variables)
#      60     U_bulk_delith = self.phase_param.U(sto_bulk, T_bulk, "delithiation")
#      61     ocp_bulk = m_lith * U_bulk_lith + m_delith * U_bulk_delith
# ---> 63 variables.update(self._get_standard_ocp_variables(ocp_surf, ocp_bulk, dUdT))
#      64 return variables
#
# UnboundLocalError: local variable 'ocp_surf' referenced before assignment

# %% [markdown]
# ## Single Cycle Simulations

# %% [markdown]
# Define a current loading

# %%
C_rate = 0.5
capacity = param["Nominal cell capacity [A.h]"]
I_load = C_rate * capacity  

t_eval = np.linspace(0,10000,1000)

param["Current function [A]"] = I_load

# %% [markdown]
# It is very easy to vary the relative volume fraction of each phase. The following example shows how to compare the results of batteries with three relative volume fractions (0.001, 0.04, 0.1) of silicon.

# %%
v_si=[0.001,0.04,0.1]
total_am_volume_fraction = 0.75
solution=[]
for v in v_si:
    param.update({
        "Primary: Negative electrode active material volume fraction": (1-v) * total_am_volume_fraction, #primary
        "Secondary: Negative electrode active material volume fraction": v * total_am_volume_fraction,
    })
    print(v)
    sim = pybamm.Simulation(
        model,
        parameter_values=param,
        solver=pybamm.CasadiSolver(dt_max = 5),
    )
    solution.append(sim.solve(t_eval = t_eval))
stop = timeit.default_timer()
print("running time: " + str(stop - start) + "s")
# Out:
# 2023-05-05 09:06:09.802 - [INFO] parameter_values.process_model(412): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 0.001
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Subtraction(-0x1150d2b7fe64973c, -, children=['concatenation(broadcast(0.0), (3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentratio...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Division(-0x47ad6ae70267e596, /, children=['concatenation(broadcast(0.0), (3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration i...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Concatenation(0x779595d182342abc, concatenation, children=['broadcast(0.0)', '(3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentrati...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(0x10d0b6475ebf2a68, *, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]', '2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol....
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(-0x303ea95a92fc8c54, *, children=['2.0 * Positive electrode exchange-current density [A.m-2]', 'sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * P...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Sinh(0x4cca232cd9edd810, function (sinh), children=['0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]))) / (Ideal gas c...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(-0x7b3df1a84e08b562, *, children=['0.5', 'Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]))) / (Ideal gas con...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Division(0x29e8aead253d8ea0, /, children=['Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])))', 'Ideal gas constant [J.K-1.m...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(0x3dc5a296ec7ceb04, *, children=['Faraday constant [C.mol-1]', 'Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]))'], domains={'primary': ['...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Subtraction(0x4823de9b3b4ec1c0, -, children=['Positive electrode potential [V] - Positive electrolyte potential [V]', '(0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])'], domains={'primary': ['positive electrode'], 'secondary':...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Addition(-0x5102b5f2e9afab51, +, children=['(0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])', '(0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(0x40a1b04414816fbe, *, children=['0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))', 'Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Addition(0x6d4effb52082e9e1, +, children=['Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))', '(Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Addition(-0x1c7e47926c27725d, +, children=['Positive electrode lithiation OCP [V]', '1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: FunctionParameter(0x521459bf0aebed68, Positive electrode lithiation OCP [V], children=['maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/util.py in __getitem__(self, key)
#      57         try:
# ---> 58             return super().__getitem__(key)
#      59         except KeyError:
#
# KeyError: 'Positive electrode lithiation OCP [V]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-8d14878b38f2> in <cell line: 4>()
#      13         solver=pybamm.CasadiSolver(dt_max = 5),
#      14     )
# ---> 15     solution.append(sim.solve(t_eval = t_eval))
#      16 stop = timeit.default_timer()
#      17 print("running time: " + str(stop - start) + "s")
#
# /usr/local/lib/python3.10/dist-packages/pybamm/simulation.py in solve(self, t_eval, solver, check_model, save_at_cycles, calc_esoh, starting_solution, initial_soc, callbacks, showprogress, **kwargs)
#     576
#     577         if self.operating_mode in ["without experiment", "drive cycle"]:
# --> 578             self.build(check_model=check_model, initial_soc=initial_soc)
#     579             if save_at_cycles is not None:
#     580                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pybamm/simulation.py in build(self, check_model, initial_soc)
#     461             self._built_model = self.model
#     462         else:
# --> 463             self.set_parameters()
#     464             self._mesh = pybamm.Mesh(self._geometry, self._submesh_types, self._var_pts)
#     465             self._disc = pybamm.Discretisation(self._mesh, self._spatial_methods)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/simulation.py in set_parameters(self)
#     411             return
#     412
# --> 413         self._model_with_set_params = self._parameter_values.process_model(
#     414             self._unprocessed_model, inplace=False
#     415         )
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_model(self, unprocessed_model, inplace)
#     436             )
#     437             new_variable = self.process_symbol(variable)
# --> 438             new_rhs[new_variable] = self.process_symbol(equation)
#     439         model.rhs = new_rhs
#     440
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     745         # Concatenations
#     746         elif isinstance(symbol, pybamm.Concatenation):
# --> 747             new_children = [self.process_symbol(child) for child in symbol.children]
#     748             return symbol._concatenation_new_copy(new_children)
#     749
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in <listcomp>(.0)
#     745         # Concatenations
#     746         elif isinstance(symbol, pybamm.Concatenation):
# --> 747             new_children = [self.process_symbol(child) for child in symbol.children]
#     748             return symbol._concatenation_new_copy(new_children)
#     749
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     740         # Functions
#     741         elif isinstance(symbol, pybamm.Function):
# --> 742             new_children = [self.process_symbol(child) for child in symbol.children]
#     743             return symbol._function_new_copy(new_children)
#     744
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in <listcomp>(.0)
#     740         # Functions
#     741         elif isinstance(symbol, pybamm.Function):
# --> 742             new_children = [self.process_symbol(child) for child in symbol.children]
#     743             return symbol._function_new_copy(new_children)
#     744
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     627
#     628         elif isinstance(symbol, pybamm.FunctionParameter):
# --> 629             function_name = self[symbol.name]
#     630             if isinstance(
#     631                 function_name,
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in __getitem__(self, key)
#     134
#     135     def __getitem__(self, key):
# --> 136         return self._dict_items[key]
#     137
#     138     def get(self, key, default=None):
#
# /usr/local/lib/python3.10/dist-packages/pybamm/util.py in __getitem__(self, key)
#      80                         f"'{key}' not found. Use the dimensional version '{k}' instead."
#      81                     )
# ---> 82             raise KeyError(f"'{key}' not found. Best matches are {best_matches}")
#      83
#      84     def search(self, key, print_values=False):
#
# KeyError: "'Positive electrode lithiation OCP [V]' not found. Best matches are ['Positive electrode OCP [V]', 'Secondary: Negative electrode lithiation OCP [V]', 'Secondary: Negative electrode delithiation OCP [V]']"

# %%
v_si=[0.001,0.04,0.1]
total_am_volume_fraction = 0.75
solution=[]
for v in v_si:
    param.update({
        "Primary: Negative electrode active material volume fraction": (1-v) * total_am_volume_fraction, #primary
        "Secondary: Negative electrode active material volume fraction": v * total_am_volume_fraction,
    })
    print(v)
    sim = pybamm.Simulation(
        model,
        parameter_values=param,
        solver=pybamm.CasadiSolver(dt_max = 5),
    )
    solution.append(sim.solve(t_eval = t_eval))
stop = timeit.default_timer()
print("running time: " + str(stop - start) + "s")
# Out:
# 2023-05-05 09:04:55.900 - [INFO] parameter_values.process_model(412): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 0.001
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Subtraction(-0x1150d2b7fe64973c, -, children=['concatenation(broadcast(0.0), (3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentratio...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Division(-0x47ad6ae70267e596, /, children=['concatenation(broadcast(0.0), (3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration i...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Concatenation(0x779595d182342abc, concatenation, children=['broadcast(0.0)', '(3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentrati...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(0x10d0b6475ebf2a68, *, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]', '2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol....
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(-0x303ea95a92fc8c54, *, children=['2.0 * Positive electrode exchange-current density [A.m-2]', 'sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * P...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Sinh(0x4cca232cd9edd810, function (sinh), children=['0.5 * Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]))) / (Ideal gas c...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(-0x7b3df1a84e08b562, *, children=['0.5', 'Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]))) / (Ideal gas con...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Division(0x29e8aead253d8ea0, /, children=['Faraday constant [C.mol-1] * (Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])))', 'Ideal gas constant [J.K-1.m...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(0x3dc5a296ec7ceb04, *, children=['Faraday constant [C.mol-1]', 'Positive electrode potential [V] - Positive electrolyte potential [V] - ((0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]))'], domains={'primary': ['...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Subtraction(0x4823de9b3b4ec1c0, -, children=['Positive electrode potential [V] - Positive electrolyte potential [V]', '(0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]) + (0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])'], domains={'primary': ['positive electrode'], 'secondary':...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Addition(-0x5102b5f2e9afab51, +, children=['(0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])', '(0.5 - (0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Positive electrode delithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Multiplication(0x40a1b04414816fbe, *, children=['0.5 + 0.5 * tanh(100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))', 'Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Addition(0x6d4effb52082e9e1, +, children=['Positive electrode lithiation OCP [V] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))', '(Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: Addition(-0x1c7e47926c27725d, +, children=['Positive electrode lithiation OCP [V]', '1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     602         try:
# --> 603             return self._processed_symbols[symbol]
#     604         except KeyError:
#
# KeyError: FunctionParameter(0x521459bf0aebed68, Positive electrode lithiation OCP [V], children=['maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pybamm/util.py in __getitem__(self, key)
#      57         try:
# ---> 58             return super().__getitem__(key)
#      59         except KeyError:
#
# KeyError: 'Positive electrode lithiation OCP [V]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-8d14878b38f2> in <cell line: 4>()
#      13         solver=pybamm.CasadiSolver(dt_max = 5),
#      14     )
# ---> 15     solution.append(sim.solve(t_eval = t_eval))
#      16 stop = timeit.default_timer()
#      17 print("running time: " + str(stop - start) + "s")
#
# /usr/local/lib/python3.10/dist-packages/pybamm/simulation.py in solve(self, t_eval, solver, check_model, save_at_cycles, calc_esoh, starting_solution, initial_soc, callbacks, showprogress, **kwargs)
#     576
#     577         if self.operating_mode in ["without experiment", "drive cycle"]:
# --> 578             self.build(check_model=check_model, initial_soc=initial_soc)
#     579             if save_at_cycles is not None:
#     580                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pybamm/simulation.py in build(self, check_model, initial_soc)
#     461             self._built_model = self.model
#     462         else:
# --> 463             self.set_parameters()
#     464             self._mesh = pybamm.Mesh(self._geometry, self._submesh_types, self._var_pts)
#     465             self._disc = pybamm.Discretisation(self._mesh, self._spatial_methods)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/simulation.py in set_parameters(self)
#     411             return
#     412
# --> 413         self._model_with_set_params = self._parameter_values.process_model(
#     414             self._unprocessed_model, inplace=False
#     415         )
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_model(self, unprocessed_model, inplace)
#     436             )
#     437             new_variable = self.process_symbol(variable)
# --> 438             new_rhs[new_variable] = self.process_symbol(equation)
#     439         model.rhs = new_rhs
#     440
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     745         # Concatenations
#     746         elif isinstance(symbol, pybamm.Concatenation):
# --> 747             new_children = [self.process_symbol(child) for child in symbol.children]
#     748             return symbol._concatenation_new_copy(new_children)
#     749
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in <listcomp>(.0)
#     745         # Concatenations
#     746         elif isinstance(symbol, pybamm.Concatenation):
# --> 747             new_children = [self.process_symbol(child) for child in symbol.children]
#     748             return symbol._concatenation_new_copy(new_children)
#     749
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     740         # Functions
#     741         elif isinstance(symbol, pybamm.Function):
# --> 742             new_children = [self.process_symbol(child) for child in symbol.children]
#     743             return symbol._function_new_copy(new_children)
#     744
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in <listcomp>(.0)
#     740         # Functions
#     741         elif isinstance(symbol, pybamm.Function):
# --> 742             new_children = [self.process_symbol(child) for child in symbol.children]
#     743             return symbol._function_new_copy(new_children)
#     744
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     715             # process children
#     716             new_left = self.process_symbol(symbol.left)
# --> 717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#     719             new_symbol = symbol._binary_new_copy(new_left, new_right)
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     714         elif isinstance(symbol, pybamm.BinaryOperator):
#     715             # process children
# --> 716             new_left = self.process_symbol(symbol.left)
#     717             new_right = self.process_symbol(symbol.right)
#     718             # make new symbol, ensure domain remains the same
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in process_symbol(self, symbol)
#     603             return self._processed_symbols[symbol]
#     604         except KeyError:
# --> 605             processed_symbol = self._process_symbol(symbol)
#     606             self._processed_symbols[symbol] = processed_symbol
#     607
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in _process_symbol(self, symbol)
#     627
#     628         elif isinstance(symbol, pybamm.FunctionParameter):
# --> 629             function_name = self[symbol.name]
#     630             if isinstance(
#     631                 function_name,
#
# /usr/local/lib/python3.10/dist-packages/pybamm/parameters/parameter_values.py in __getitem__(self, key)
#     134
#     135     def __getitem__(self, key):
# --> 136         return self._dict_items[key]
#     137
#     138     def get(self, key, default=None):
#
# /usr/local/lib/python3.10/dist-packages/pybamm/util.py in __getitem__(self, key)
#      80                         f"'{key}' not found. Use the dimensional version '{k}' instead."
#      81                     )
# ---> 82             raise KeyError(f"'{key}' not found. Best matches are {best_matches}")
#      83
#      84     def search(self, key, print_values=False):
#
# KeyError: "'Positive electrode lithiation OCP [V]' not found. Best matches are ['Positive electrode OCP [V]', 'Secondary: Negative electrode lithiation OCP [V]', 'Secondary: Negative electrode delithiation OCP [V]']"

# %% [markdown]
# ## Results
# Compare the cell voltages of the three cells in this example, to see how silicon affects the output capacity

# %%
ltype=['k-','r--','b-.','g:','m-','c--','y-.'];
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    V_i = solution[i]["Terminal voltage [V]"].entries
    plt.plot(t_i, V_i,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel('Terminal voltage [V]')
plt.legend()

# %% [markdown]
# Results of interfacial current density in silicon

# %%
plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    j_n_p1_av = solution[i]["X-averaged negative electrode primary interfacial current density [A.m-2]"].entries
    plt.plot(t_i, j_n_p1_av,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel('Averaged interfacial current density [A/m$^{2}$]')
plt.legend()
plt.title('Graphite')

plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    j_n_p2_av = solution[i]["X-averaged negative electrode secondary interfacial current density [A.m-2]"].entries
    plt.plot(t_i, j_n_p2_av,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel('Averaged interfacial current density [A/m$^{2}$]')
plt.legend()
plt.title('Silicon')
# Out:
# Text(0.5, 1.0, 'Silicon')

# %% [markdown]
# Results of interfacial current density in graphite

# %%
plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    j_n_p1_Vav = solution[i]["X-averaged negative electrode primary volumetric interfacial current density [A.m-3]"].entries
    plt.plot(t_i, j_n_p1_Vav,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel('Averaged volumetric interfacial current density [A/m$^{3}$]')
plt.legend()
plt.title('Graphite')

plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    j_n_p2_Vav = solution[i]["X-averaged negative electrode secondary volumetric interfacial current density [A.m-3]"].entries
    plt.plot(t_i, j_n_p2_Vav,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel('Averaged volumetric interfacial current density [A/m$^{3}$]')
plt.legend()
plt.title('Silicon')
# Out:
# Text(0.5, 1.0, 'Silicon')

# %% [markdown]
# Results of average lithium concentration

# %%
plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    c_s_xrav_n_p1 = solution[i]["Average negative primary particle concentration"].entries
    plt.plot(t_i, c_s_xrav_n_p1 ,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel("$c_\mathrm{g}/c_\mathrm{g,max}$")
plt.legend()
plt.title('Graphite')

plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    c_s_xrav_n_p2 = solution[i]["Average negative secondary particle concentration"].entries
    plt.plot(t_i, c_s_xrav_n_p2,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel("$c_\mathrm{si}/c_\mathrm{si,max}$")
plt.legend()
plt.title('Silicon')
# Out:
# Text(0.5, 1.0, 'Silicon')

# %% [markdown]
# Results of equilibrium potential

# %%
plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    ocp_p1 = solution[i]["X-averaged negative electrode primary open circuit potential [V]"].entries
    plt.plot(t_i, ocp_p1 ,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel("Equilibruim potential [V]")
plt.legend()
plt.title('Graphite')

plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    ocp_p2 = solution[i]["X-averaged negative electrode secondary open circuit potential [V]"].entries
    plt.plot(t_i, ocp_p2,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel("Equilibruim potential [V]")
plt.legend()
plt.title('Silicon')

plt.figure()
for i in range(0,len(v_si)):
    t_i = solution[len(v_si)- 1 - i]["Time [s]"].entries / 3600
    ocp_p = solution[len(v_si)- 1 - i]["X-averaged positive electrode open circuit potential [V]"].entries
    plt.plot(t_i, ocp_p,ltype[len(v_si)- 1 - i],label="$V_\mathrm{si}=$"+str(v_si[len(v_si)- 1 - i]))
plt.xlabel('Time [h]')
plt.ylabel("Equilibrium potential [V]")
plt.legend()
plt.title('NMC811')
# Out:
# Text(0.5, 1.0, 'NMC811')

# %% [markdown]
# ## Multi-Cycle Simulations
# For multi-cycling, an experiment definition for static C/2 discharge and charge cycling is presented.

# %%
experiment = pybamm.Experiment(
    [
        (
            "Discharge at C/2 until 3.0 V",
            "Rest for 1 hour",
            "Charge at C/2 until 4.2 V",
            "Rest for 1 hour",
        ),
    ]
    * 2
)

# %% [markdown]
# The solution is reintroduced, with `calc_esoh=False` passed into the solve function. Currently, composite electrode state of health predictions are not included in this model.

# %%
solution=[]
for v in v_si:
    param.update({
        "Primary: Negative electrode active material volume fraction": (1-v) * total_am_volume_fraction, #primary
        "Secondary: Negative electrode active material volume fraction": v * total_am_volume_fraction,
    })
    print(v)
    sim = pybamm.Simulation(
        model,
        experiment=experiment,
        parameter_values=param,
        solver=pybamm.CasadiSolver(dt_max = 5)
    )
    solution.append(sim.solve(calc_esoh=False))
stop = timeit.default_timer()
print("running time: " + str(stop - start) + "s")
# Out:
# 2023-02-24 13:13:06.837 - [INFO] callbacks.on_experiment_start(166): Start running experiment
# INFO:pybamm.logger:Start running experiment
# 2023-02-24 13:13:06.844 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 0.001
# 2023-02-24 13:13:07.122 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:07.129 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:07.374 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:07.383 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:07.608 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:07.618 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:07.637 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:08.968 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:08.976 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:08.996 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:09.997 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:10.003 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:10.025 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:11.081 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:11.088 - [NOTICE] callbacks.on_cycle_start(174): Cycle 1/2 (63.485 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/2 (63.485 us elapsed) --------------------
# 2023-02-24 13:13:11.093 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 1/4: Discharge at C/2 until 3.0 V
# NOTICE:pybamm.logger:Cycle 1/2, step 1/4: Discharge at C/2 until 3.0 V
# 2023-02-24 13:13:11.115 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:11.412 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:13.723 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 2/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/2, step 2/4: Rest for 1 hour
# 2023-02-24 13:13:13.737 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:13.901 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:15.004 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 3/4: Charge at C/2 until 4.2 V
# NOTICE:pybamm.logger:Cycle 1/2, step 3/4: Charge at C/2 until 4.2 V
# 2023-02-24 13:13:15.016 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:15.185 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:16.956 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 4/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/2, step 4/4: Rest for 1 hour
# 2023-02-24 13:13:18.236 - [NOTICE] callbacks.on_cycle_start(174): Cycle 2/2 (7.148 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/2 (7.148 s elapsed) --------------------
# 2023-02-24 13:13:18.244 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 1/4: Discharge at C/2 until 3.0 V
# NOTICE:pybamm.logger:Cycle 2/2, step 1/4: Discharge at C/2 until 3.0 V
# 2023-02-24 13:13:19.950 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 2/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 2/2, step 2/4: Rest for 1 hour
# 2023-02-24 13:13:21.041 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 3/4: Charge at C/2 until 4.2 V
# NOTICE:pybamm.logger:Cycle 2/2, step 3/4: Charge at C/2 until 4.2 V
# 2023-02-24 13:13:23.214 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 4/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 2/2, step 4/4: Rest for 1 hour
# 2023-02-24 13:13:25.092 - [NOTICE] callbacks.on_experiment_end(222): Finish experiment simulation, took 14.004 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 14.004 s
# 2023-02-24 13:13:25.103 - [INFO] callbacks.on_experiment_start(166): Start running experiment
# INFO:pybamm.logger:Start running experiment
# 2023-02-24 13:13:25.112 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 0.04
# 2023-02-24 13:13:25.359 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:25.366 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:25.591 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:25.599 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:25.823 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:25.834 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:25.851 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:26.904 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:26.913 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:26.937 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:27.824 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:27.832 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:27.847 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:28.497 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:28.503 - [NOTICE] callbacks.on_cycle_start(174): Cycle 1/2 (37.240 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/2 (37.240 us elapsed) --------------------
# 2023-02-24 13:13:28.510 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 1/4: Discharge at C/2 until 3.0 V
# NOTICE:pybamm.logger:Cycle 1/2, step 1/4: Discharge at C/2 until 3.0 V
# 2023-02-24 13:13:28.525 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:28.696 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:31.118 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 2/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/2, step 2/4: Rest for 1 hour
# 2023-02-24 13:13:31.131 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:31.289 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:32.322 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 3/4: Charge at C/2 until 4.2 V
# NOTICE:pybamm.logger:Cycle 1/2, step 3/4: Charge at C/2 until 4.2 V
# 2023-02-24 13:13:32.338 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:32.523 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:34.616 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 4/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/2, step 4/4: Rest for 1 hour
# 2023-02-24 13:13:35.866 - [NOTICE] callbacks.on_cycle_start(174): Cycle 2/2 (7.363 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/2 (7.363 s elapsed) --------------------
# 2023-02-24 13:13:35.874 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 1/4: Discharge at C/2 until 3.0 V
# NOTICE:pybamm.logger:Cycle 2/2, step 1/4: Discharge at C/2 until 3.0 V
# 2023-02-24 13:13:38.537 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 2/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 2/2, step 2/4: Rest for 1 hour
# 2023-02-24 13:13:40.146 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 3/4: Charge at C/2 until 4.2 V
# NOTICE:pybamm.logger:Cycle 2/2, step 3/4: Charge at C/2 until 4.2 V
# 2023-02-24 13:13:42.937 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 4/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 2/2, step 4/4: Rest for 1 hour
# 2023-02-24 13:13:44.081 - [NOTICE] callbacks.on_experiment_end(222): Finish experiment simulation, took 15.578 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 15.578 s
# 2023-02-24 13:13:44.090 - [INFO] callbacks.on_experiment_start(166): Start running experiment
# INFO:pybamm.logger:Start running experiment
# 2023-02-24 13:13:44.096 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:44.232 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:44.239 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 0.1
# 2023-02-24 13:13:44.389 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:44.396 - [INFO] parameter_values.process_model(425): Start setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:44.531 - [INFO] parameter_values.process_model(527): Finish setting parameters for Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish setting parameters for Doyle-Fuller-Newman model
# 2023-02-24 13:13:44.542 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:44.558 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:45.211 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:45.217 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:45.237 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:45.889 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:45.896 - [INFO] discretisation.process_model(148): Start discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Start discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:45.913 - [INFO] discretisation.remove_independent_variables_from_rhs(1123): removing variable Discharge capacity [A.h] from rhs
# INFO:pybamm.logger:removing variable Discharge capacity [A.h] from rhs
# 2023-02-24 13:13:46.566 - [INFO] discretisation.process_model(260): Finish discretising Doyle-Fuller-Newman model
# INFO:pybamm.logger:Finish discretising Doyle-Fuller-Newman model
# 2023-02-24 13:13:46.571 - [NOTICE] callbacks.on_cycle_start(174): Cycle 1/2 (37.785 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/2 (37.785 us elapsed) --------------------
# 2023-02-24 13:13:46.575 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 1/4: Discharge at C/2 until 3.0 V
# NOTICE:pybamm.logger:Cycle 1/2, step 1/4: Discharge at C/2 until 3.0 V
# 2023-02-24 13:13:46.585 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:46.754 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:49.518 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 2/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/2, step 2/4: Rest for 1 hour
# 2023-02-24 13:13:49.534 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:49.886 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:50.888 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 3/4: Charge at C/2 until 4.2 V
# NOTICE:pybamm.logger:Cycle 1/2, step 3/4: Charge at C/2 until 4.2 V
# 2023-02-24 13:13:50.900 - [INFO] base_solver.set_up(111): Start solver set-up
# INFO:pybamm.logger:Start solver set-up
# 2023-02-24 13:13:51.061 - [INFO] base_solver.set_up(236): Finish solver set-up
# INFO:pybamm.logger:Finish solver set-up
# 2023-02-24 13:13:54.422 - [NOTICE] callbacks.on_step_start(182): Cycle 1/2, step 4/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/2, step 4/4: Rest for 1 hour
# 2023-02-24 13:13:56.562 - [NOTICE] callbacks.on_cycle_start(174): Cycle 2/2 (9.991 s elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/2 (9.991 s elapsed) --------------------
# 2023-02-24 13:13:56.569 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 1/4: Discharge at C/2 until 3.0 V
# NOTICE:pybamm.logger:Cycle 2/2, step 1/4: Discharge at C/2 until 3.0 V
# 2023-02-24 13:13:59.164 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 2/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 2/2, step 2/4: Rest for 1 hour
# 2023-02-24 13:14:00.156 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 3/4: Charge at C/2 until 4.2 V
# NOTICE:pybamm.logger:Cycle 2/2, step 3/4: Charge at C/2 until 4.2 V
# 2023-02-24 13:14:02.542 - [NOTICE] callbacks.on_step_start(182): Cycle 2/2, step 4/4: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 2/2, step 4/4: Rest for 1 hour
# 2023-02-24 13:14:03.945 - [NOTICE] callbacks.on_experiment_end(222): Finish experiment simulation, took 17.374 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 17.374 s
# running time: 1087.9241556460001s

# %% [markdown]
# ## Cycling Results
# The previously displayed single discharge results can be extended to the cycling solution. As an example, terminal voltage is displayed below.

# %%
ltype=['k-','r--','b-.','g:','m-','c--','y-.'];
for i in range(0,len(v_si)):
    t_i = solution[i]["Time [s]"].entries / 3600
    V_i = solution[i]["Terminal voltage [V]"].entries
    plt.plot(t_i, V_i,ltype[i],label="$V_\mathrm{si}=$"+str(v_si[i]))
plt.xlabel('Time [h]')
plt.ylabel('Terminal voltage [V]')
plt.legend()

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
# Out:
# [1] Weilong Ai, Niall Kirkaldy, Yang Jiang, Gregory Offer, Huizhi Wang, and Billy Wu. A composite electrode model for lithium-ion batteries with silicon/graphite negative electrodes. Journal of Power Sources, 527:231142, 2022. URL: https://www.sciencedirect.com/science/article/pii/S0378775322001604, doi:https://doi.org/10.1016/j.jpowsour.2022.231142.
# [2] Weilong Ai, Ludwig Kraft, Johannes Sturm, Andreas Jossen, and Billy Wu. Electrochemical thermal-mechanical modelling of stress inhomogeneity in lithium-ion pouch cells. Journal of The Electrochemical Society, 167(1):013512, 2019. doi:10.1149/2.0122001JES.
# [3] Joel A. E. Andersson, Joris Gillis, Greg Horn, James B. Rawlings, and Moritz Diehl. CasADi – A software framework for nonlinear optimization and optimal control. Mathematical Programming Computation, 11(1):1–36, 2019. doi:10.1007/s12532-018-0139-4.
# [4] Chang-Hui Chen, Ferran Brosa Planella, Kieran O'Regan, Dominika Gastol, W. Dhammika Widanage, and Emma Kendrick. Development of Experimental Techniques for Parameterization of Multi-scale Lithium-ion Battery Models. Journal of The Electrochemical Society, 167(8):080534, 2020. doi:10.1149/1945-7111/ab9050.
# [5] Rutooj Deshpande, Mark Verbrugge, Yang-Tse Cheng, John Wang, and Ping Liu. Battery cycle life prediction with coupled chemical degradation and fatigue mechanics. Journal of the Electrochemical Society, 159(10):A1730, 2012. doi:10.1149/2.049210jes.
# [6] Marc Doyle, Thomas F. Fuller, and John Newman. Modeling of galvanostatic charge and discharge of the lithium/polymer/insertion cell. Journal of the Electrochemical society, 140(6):1526–1533, 1993. doi:10.1149/1.2221597.
# [7] Charles R. Harris, K. Jarrod Millman, Stéfan J. van der Walt, Ralf Gommers, Pauli Virtanen, David Cournapeau, Eric Wieser, Julian Taylor, Sebastian Berg, Nathaniel J. Smith, and others. Array programming with NumPy. Nature, 585(7825):357–362, 2020. doi:10.1038/s41586-020-2649-2.
# [8] Valentin Sulzer, Scott G. Marquis, Robert Timms, Martin Robinson, and S. Jon Chapman. Python Battery Mathematical Modelling (PyBaMM). Journal of Open Research Software, 9(1):14, 2021. doi:10.5334/jors.309.
